-- %%
%python
df = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

-- %%
%python
dbutils.widgets.text("layer", "silver")
dbutils.widgets.text("month", "2019-Oct")

layer = dbutils.widgets.get("layer")
month = dbutils.widgets.get("month")

print("Layer:", layer)
print("Month:", month)
-- Out:
-- Layer: silver
-- Month: 2019-Oct

-- %%
%python
dbutils.widgets.text("month","2019-Oct")
month = dbutils.widgets.get("month")

path = f"/Volumes/workspace/ecommerce/ecommerce_data/{month}.csv"
df = spark.read.csv(path)

-- %%
%python
df = spark.read.csv(
    path,
    header=True,
    inferSchema=True
)

-- %%
%python
df.printSchema()
-- Out:
-- root
--  |-- event_time: timestamp (nullable = true)
--  |-- event_type: string (nullable = true)
--  |-- product_id: integer (nullable = true)
--  |-- category_id: long (nullable = true)
--  |-- category_code: string (nullable = true)
--  |-- brand: string (nullable = true)
--  |-- price: double (nullable = true)
--  |-- user_id: integer (nullable = true)
--  |-- user_session: string (nullable = true)

-- %%
%python
def clean_data(df):
    # example cleaning
    df = df.dropna()
    return df
def create_features(df):
    # example feature
    from pyspark.sql.functions import col
    
    df = df.withColumn("total_price", col("quantity") * col("price"))
    return df

def save_table(df, layer):
    df.write.mode("overwrite").saveAsTable(f"ecommerce_{layer}")
