# %%
df = spark.read.format("csv") \
    .option("header","true") \
    .option("inferSchema","true") \
    .load("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

df_sample = df.limit(300)

# %%
import time

start = time.time()

df = spark.sql("""
SELECT user_id, COUNT(*) as total_purchases
FROM events_delta
WHERE event_type = 'purchase'
GROUP BY user_id
""")

df.show()

end = time.time()
print("Execution time:", end - start)
# Out:
# +---------+---------------+
# |  user_id|total_purchases|
# +---------+---------------+
# |562785709|              2|
# |559882492|              2|
# |515126999|              2|
# |560127436|             21|
# |512860682|              4|
# |514738870|              7|
# |515025844|              3|
# |549256733|              1|
# |519393303|              2|
# |542076641|              1|
# |524566828|             22|
# |522415286|              1|
# |551524811|              3|
# |512370169|              6|
# |513998281|              1|
# |517096288|              7|
# |547289834|              1|
# |512972438|              2|
# |514141844|              8|
# |542769532|              1|
# +---------+---------------+
# only showing top 20 rows
# Execution time: 5.674102067947388

# %%
df.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['user_id], ['user_id, 'COUNT(1) AS total_purchases#13287]
# +- 'Filter ('event_type = purchase)
#    +- 'UnresolvedRelation [events_delta], [], false
#
# == Analyzed Logical Plan ==
# user_id: int, total_purchases: bigint
# Aggregate [user_id#13325], [user_id#13325, count(1) AS total_purchases#13287L]
# +- Filter (event_type#13319 = purchase)
#    +- SubqueryAlias workspace.default.events_delta
#       +- Relation workspace.default.events_delta[event_time#13318,event_type#13319,product_id#13320,category_id#13321L,category_code#13322,brand#13323,price#13324,user_id#13325,user_session#13326] parquet
#
# == Optimized Logical Plan ==
# Aggregate [user_id#13325], [user_id#13325, count(1) AS total_purchases#13287L]
# +- Project [user_id#13325]
#    +- Filter (isnotnull(event_type#13319) AND (event_type#13319 = purchase))
#       +- Relation workspace.default.events_delta[event_time#13318,event_type#13319,product_id#13320,category_id#13321L,category_code#13322,brand#13323,price#13324,user_id#13325,user_session#13326] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    PhotonResultStage
#    +- PhotonColumnarToRow
#       +- PhotonGroupingAgg(limit=None, keys=[user_id#13325], functions=[finalmerge_count(merge count#13338L) AS count(1)#13327L], output=[user_id#13325, total_purchases#13287L])
#          +- PhotonShuffleExchangeSource
#             +- PhotonShuffleMapStage ENSURE_REQUIREMENTS, [id=#8324]
#                +- PhotonShuffleExchangeSink hashpartitioning(user_id#13325, 1024)
#                   +- PhotonGroupingAgg(limit=None, keys=[user_id#13325], functions=[partial_count(1) AS count#13338L], output=[user_id#13325, count#13338L])
#                      +- PhotonProject [user_id#13325]
#                         +- PhotonScan parquet workspace.default.events_delta[event_type#13319,user_id#13325] DataFilters: [isnotnull(event_type#13319), (event_type#13319 = purchase)], DictionaryFilters: [(event_type#13319 = purchase)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-y0kfc/uc/ffa70383-5ad1-4918-ab41-1d035db5acb6..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<event_type:string,user_id:int>, RequiredDataFilters: [isnotnull(event_type#13319), (event_type#13319 = purchase)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial =
#   full    = events_delta

# %%
spark.sql("DESCRIBE DETAIL events_delta").show(truncate=False)
# Out:
# +------+------------------------------------+------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                          |description|location|createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |89ce5580-363e-446d-a707-d6a74961ec6f|workspace.default.events_delta|NULL       |        |2026-02-21 02:17:35.606|2026-02-28 18:59:23|[]              |[]               |27      |1439838839 |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+

# %% [markdown]
# # Recreating table with partitioning (to optimize the search)

# %%
events_df = spark.table("events_delta")

# %%
events_df.write \
    .format("delta") \
    .partitionBy("event_type") \
    .mode("overwrite") \
    .saveAsTable("events_delta_partitioned")

# %%
spark.sql("DESCRIBE DETAIL events_delta_partitioned").show(truncate=False)
# Out:
# +------+------------------------------------+------------------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                                      |description|location|createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                                                                    |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+------------------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |5405ef70-5a3c-470d-86a9-65b09e880575|workspace.default.events_delta_partitioned|NULL       |        |2026-03-02 04:17:28.892|2026-03-02 04:17:45|[event_type]    |[]               |7       |760205444  |{delta.parquet.compression.codec -> zstd, delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+------------------------------------------+-----------+--------+-----------------------+-------------------+----------------+-----------------+--------+-----------+------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+

# %%
spark.sql("""
SELECT * FROM events_delta_partitioned
WHERE event_type = 'purchase'
""").explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Project [*]
# +- 'Filter ('event_type = purchase)
#    +- 'UnresolvedRelation [events_delta_partitioned], [], false
#
# == Analyzed Logical Plan ==
# event_time: timestamp, event_type: string, product_id: int, category_id: bigint, category_code: string, brand: string, price: double, user_id: int, user_session: string
# Project [event_time#14095, event_type#14096, product_id#14097, category_id#14098L, category_code#14099, brand#14100, price#14101, user_id#14102, user_session#14103]
# +- Filter (event_type#14096 = purchase)
#    +- SubqueryAlias workspace.default.events_delta_partitioned
#       +- Relation workspace.default.events_delta_partitioned[event_time#14095,event_type#14096,product_id#14097,category_id#14098L,category_code#14099,brand#14100,price#14101,user_id#14102,user_session#14103] parquet
#
# == Optimized Logical Plan ==
# Filter (isnotnull(event_type#14096) AND (event_type#14096 = purchase))
# +- Relation workspace.default.events_delta_partitioned[event_time#14095,event_type#14096,product_id#14097,category_id#14098L,category_code#14099,brand#14100,price#14101,user_id#14102,user_session#14103] parquet
#
# == Physical Plan ==
# PhotonResultStage
# +- PhotonColumnarToRow
#    +- PhotonProject [event_time#14095, event_type#14096, product_id#14097, category_id#14098L, category_code#14099, brand#14100, price#14101, user_id#14102, user_session#14103]
#       +- PhotonScan parquet workspace.default.events_delta_partitioned[event_time#14095,product_id#14097,category_id#14098L,category_code#14099,brand#14100,price#14101,user_id#14102,user_session#14103,event_type#14096] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://dbstorage-prod-y0kfc/uc/ffa70383-5ad1-4918-ab41-1d035db5acb6..., OptionalDataFilters: [], PartitionFilters: [isnotnull(event_type#14096), (event_type#14096 = purchase)], ReadSchema: struct<event_time:timestamp,product_id:int,category_id:bigint,category_code:string,brand:string,p..., RequiredDataFilters: []
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing =
#   partial = events_delta_partitioned
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS
